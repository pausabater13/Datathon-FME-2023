# %%
#Reinforcement Learning: teching agents through trial and error

    #Agent: actor operting within a environment, usually governed by a policy (rule about actions to take)
    #Reward and Observation

# %%
#LIMITATIONS:
    #RL can be overkill for simple problems
    #Assumes the environment is Markopvian (future depends on past, no random events)
    #Training can take a long time and is not always stable

# %%
#Install swig: 
#!/bin/bash -c "$(curl -fsSL https://raw.githubusercontent.com/Homebrew/install/HEAD/install.sh)"
#!brew install swig
#!pip install "gym[box2d]" pyglet
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pyglet
#   Using cached pyglet-2.0.10-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: gym[box2d] in /Users/psabnac/Library/Python/3.9/lib/python/site-packages (0.26.2)
# Requirement already satisfied: numpy>=1.18.0 in /Library/Python/3.9/site-packages (from gym[box2d]) (1.26.1)
# Requirement already satisfied: cloudpickle>=1.2.0 in /Users/psabnac/Library/Python/3.9/lib/python/site-packages (from gym[box2d]) (3.0.0)
# Requirement already satisfied: gym-notices>=0.0.4 in /Users/psabnac/Library/Python/3.9/lib/python/site-packages (from gym[box2d]) (0.0.8)
# Requirement already satisfied: importlib-metadata>=4.8.0 in /Users/psabnac/Library/Python/3.9/lib/python/site-packages (from gym[box2d]) (6.8.0)
# Collecting box2d-py==2.3.5 (from gym[box2d])
#   Using cached box2d-py-2.3.5.tar.gz (374 kB)
#   Preparing metadata (setup.py) ... done
# Collecting pygame==2.1.0 (from gym[box2d])
#   Using cached pygame-2.1.0-cp39-cp39-macosx_10_9_x86_64.whl (5.2 MB)
# Collecting swig==4.* (from gym[box2d])
#   Using cached swig-4.1.1.post0-py2.py3-none-macosx_10_9_x86_64.whl.metadata (3.6 kB)
# Requirement already satisfied: zipp>=0.5 in /Library/Python/3.9/site-packages (from importlib-metadata>=4.8.0->gym[box2d]) (3.17.0)
# Using cached swig-4.1.1.post0-py2.py3-none-macosx_10_9_x86_64.whl (1.7 MB)
# Using cached pyglet-2.0.10-py3-none-any.whl (858 kB)
# Building wheels for collected packages: box2d-py
#   Building wheel for box2d-py (setup.py) ... done
#   Created wheel for box2d-py: filename=box2d_py-2.3.5-cp39-cp39-macosx_10_9_universal2.whl size=938715 sha256=b26a114779879e5dd4dbdf9d078a88245783d418cc166e3c1ef740b97e3d78fe
#   Stored in directory: /Users/psabnac/Library/Caches/pip/wheels/a4/c2/c1/076651c394f05fe60990cd85616c2d95bc1619aa113f559d7d
# Successfully built box2d-py
# Installing collected packages: swig, pyglet, box2d-py, pygame
#   Attempting uninstall: pygame
#     Found existing installation: pygame 2.5.2
#     Uninstalling pygame-2.5.2:
#       Successfully uninstalled pygame-2.5.2
# Successfully installed box2d-py-2.3.5 pygame-2.1.0 pyglet-2.0.10 swig-4.1.1.post0

# %%
#!pip install --upgrade pip
#!pip install stable_baselines3
#!pip3 install stable-baselines3[extra] #RL model free algorithms
#Documentation: https://stable-baselines3.readthedocs.io/en/master/guide/migration.html
#!pip install gym
#!pip instal torch==1.8.1+cu111 torchvision==0.9.1+cu111 torchaudio==0.8.1 -f https://download.pytorch.org/whl/torch_stable.html

# %% [markdown]
# #Import dependencies

# %%
import os
#import torch
import gym #OpenAI. Documentation: https://gym.openai.com/docs/
# https://stable-baselines3.readthedocs.io/en/master/guide/rl.html
# https://spinningup.openai.com/en/latest/spinningup/rl_intro2.html#a-taxonomy-of-rl-algorithms
from stable_baselines3 import PPO #algorithm
from stable_baselines3.common.vec_env import DummyVecEnv #vectorize environment, train multiple RL agents at the same time
from stable_baselines3.common.evaluation import evaluate_policy #testing
# Out:
# 2023-11-09 19:43:09.652976: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /Users/psabnac/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %% [markdown]
# Test Environment

# %%
environment_name = "CarRacing-v2"
env = gym.make(environment_name, render_mode="human")

# %%
env.reset()
env.action_space
env.observation_space
env.render()
# Out:
# True

# %%
env.close()

# %%
episodes = 5
for episode in range(1, episodes+1):
    obs = env.reset()
    done = False
    score = 0

    while not done:
        env.render()
        action = env.action_space.sample()
        obs, reward, done, _, info = env.step(action)
        score += reward
    print('Episode:{} Score:{}'.format(episode,score))
#env.close()
# Out:
# /Users/psabnac/Library/Python/3.9/lib/python/site-packages/gym/utils/passive_env_checker.py:233: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/psabnac/Downloads/MLReinforcementLearning Driving/ML_RL_.ipynb Cell 11 line 8
#       <a href='vscode-notebook-cell:/Users/psabnac/Downloads/MLReinforcementLearning%20Driving/ML_RL_.ipynb#X13sZmlsZQ%3D%3D?line=4'>5</a> score = 0
#       <a href='vscode-notebook-cell:/Users/psabnac/Downloads/MLReinforcementLearning%20Driving/ML_RL_.ipynb#X13sZmlsZQ%3D%3D?line=6'>7</a> while not done:
# ----> <a href='vscode-notebook-cell:/Users/psabnac/Downloads/MLReinforcementLearning%20Driving/ML_RL_.ipynb#X13sZmlsZQ%3D%3D?line=7'>8</a>     env.render()
#       <a href='vscode-notebook-cell:/Users/psabnac/Downloads/MLReinforcementLearning%20Driving/ML_RL_.ipynb#X13sZmlsZQ%3D%3D?line=8'>9</a>     action = env.action_space.sample()
#      <a href='vscode-notebook-cell:/Users/psabnac/Downloads/MLReinforcementLearning%20Driving/ML_RL_.ipynb#X13sZmlsZQ%3D%3D?line=9'>10</a>     obs, reward, done, _, info = env.step(action)
#
# File ~/Library/Python/3.9/lib/python/site-packages/gym/core.py:329, in Wrapper.render(self, *args, **kwargs)
#     325 def render(
#     326     self, *args, **kwargs
#     327 ) -> Optional[Union[RenderFrame, List[RenderFrame]]]:
#     328     """Renders the environment."""
# --> 329     return self.env.render(*args, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/gym/wrappers/order_enforcing.py:51, in OrderEnforcing.render(self, *args, **kwargs)
#      46 if not self._disable_render_order_enforcing and not self._has_reset:
#      47     raise ResetNeeded(
#      48         "Cannot call `env.render()` before calling `env.reset()`, if this is a intended action, "
#      49         "set `disable_render_order_enforcing=True` on the OrderEnforcer wrapper."
#      50     )
# ---> 51 return self.env.render(*args, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/gym/wrappers/env_checker.py:55, in PassiveEnvChecker.render(self, *args, **kwargs)
#      53     return env_render_passive_checker(self.env, *args, **kwargs)
#      54 else:
# ---> 55     return self.env.render(*args, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/gym/envs/box2d/car_racing.py:575, in CarRacing.render(self)
#     569     gym.logger.warn(
#     570         "You are calling render method without specifying any render mode. "
#     571         "You can specify the render_mode at initialization, "
#     572         f'e.g. gym("{self.spec.id}", render_mode="rgb_array")'
#     573     )
#     574 else:
# --> 575     return self._render(self.render_mode)
#
# File ~/Library/Python/3.9/lib/python/site-packages/gym/envs/box2d/car_racing.py:615, in CarRacing._render(self, mode)
#     612 self.surf = pygame.transform.flip(self.surf, False, True)
#     614 # showing stats
# --> 615 self._render_indicators(WINDOW_W, WINDOW_H)
#     617 font = pygame.font.Font(pygame.font.get_default_font(), 42)
#     618 text = font.render("%04i" % self.reward, True, (255, 255, 255), (0, 0, 0))
#
# File ~/Library/Python/3.9/lib/python/site-packages/gym/envs/box2d/car_racing.py:681, in CarRacing._render_indicators(self, W, H)
#     679 color = (0, 0, 0)
#     680 polygon = [(W, H), (W, H - 5 * h), (0, H - 5 * h), (0, H)]
# --> 681 pygame.draw.polygon(self.surf, color=color, points=polygon)
#     683 def vertical_ind(place, val):
#     684     return [
#     685         (place * s, H - (h + h * val)),
#     686         ((place + 1) * s, H - (h + h * val)),
#     687         ((place + 1) * s, H - h),
#     688         ((place + 0) * s, H - h),
#     689     ]
#
# KeyboardInterrupt:

# %% [markdown]
# #Train RL Model:

# %%
#env??
# Out:
# Type:           TimeLimit
# String form:    <TimeLimit<OrderEnforcing<PassiveEnvChecker<CarRacing<CarRacing-v2>>>>>
# File:           ~/Library/Python/3.9/lib/python/site-packages/gym/wrappers/time_limit.py
# Source:
# class TimeLimit(gym.Wrapper):
#     """This wrapper will issue a `truncated` signal if a maximum number of timesteps is exceeded.
#
#     If a truncation is not defined inside the environment itself, this is the only place that the truncation signal is issued.
#     Critically, this is different from the `terminated` signal that originates from the underlying environment as part of the MDP.
#
#     Example:
#        >>> from gym.envs.classic_control import CartPoleEnv
#        >>> from gym.wrappers import TimeLimit
#        >>> env = CartPoleEnv()
#        >>> env = TimeLimit(env, max_episode_steps=1000)
#     """
#
#     def __init__(
#         self,
#         env: gym.Env,
#         max_episode_steps: Optional[int] = None,
#     ):
#         """Initializes the :class:`TimeLimit` wrapper with an environment and the number of steps after which truncation will occur.
#
#         Args:
#             env: The environment to apply the wrapper
#             max_episode_steps: An optional max episode steps (if ``Ǹone``, ``env.spec.max_episode_steps`` is used)
#         """
#         super().__init__(env)
#         if max_episode_steps is None and self.env.spec is not None:
#             max_episode_steps = env.spec.max_episode_steps
#         if self.env.spec is not None:
#             self.env.spec.max_episode_steps = max_episode_steps
#         self._max_episode_steps = max_episode_steps
#         self._elapsed_steps = None
#
#     def step(self, action):
#         """Steps through the environment and if the number of steps elapsed exceeds ``max_episode_steps`` then truncate.
#
#         Args:
#             action: The environment step action
#
#         Returns:
#             The environment step ``(observation, reward, terminated, truncated, info)`` with `truncated=True`
#             if the number of steps elapsed >= max episode steps
#
#         """
#         observation, reward, terminated, truncated, info = self.env.step(action)
#         self._elapsed_steps += 1
#
#         if self._elapsed_steps >= self._max_episode_steps:
#             truncated = True
#
#         return observation, reward, terminated, truncated, info
#
#     def reset(self, **kwargs):
#         """Resets the environment with :param:`**kwargs` and sets the number of steps elapsed to zero.
#
#         Args:
#             **kwargs: The kwargs to reset the environment with
#
#         Returns:
#             The reset environment
#         """
#         self._elapsed_steps = 0
#         return self.env.reset(**kwargs)
# Init docstring:
# Initializes the :class:`TimeLimit` wrapper with an environment and the number of steps after which truncation will occur.
#
# Args:
#     env: The environment to apply the wrapper
#     max_episode_steps: An optional max episode steps (if ``Ǹone``, ``env.spec.max_episode_steps`` is used)

# %%
#MAKE DIRECTORIES FIRST
log_path = os.path.join('Training', 'Logs') #/Training/Logs

# %%
env = gym.make(environment_name)
env = DummyVecEnv([lambda: env])
model = PPO('MlpPolicy', env, verbose = 1) #(policy(MultiPerceptron), )
#PPO??
# Out:
# /Users/psabnac/Library/Python/3.9/lib/python/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# Using cpu device
# Wrapping the env in a VecTransposeImage.

# %%
model.learn(total_timesteps=100000)
# Out:
# /Users/psabnac/Library/Python/3.9/lib/python/site-packages/gym/utils/passive_env_checker.py:233: DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(terminated, (bool, np.bool8)):
# -----------------------------
# | time/              |      |
# |    fps             | 51   |
# |    iterations      | 1    |
# |    time_elapsed    | 39   |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 41          |
# |    iterations           | 2           |
# |    time_elapsed         | 99          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.006101002 |
# |    clip_fraction        | 0.071       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.25       |
# |    explained_variance   | -0.0051     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.334       |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00498    |
# |    std                  | 0.996       |
# |    value_loss           | 1.78        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 38           |
# |    iterations           | 3            |
# |    time_elapsed         | 160          |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0059214104 |
# |    clip_fraction        | 0.0564       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.25        |
# |    explained_variance   | 0.00326      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.229        |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00388     |
# |    std                  | 0.998        |
# |    value_loss           | 0.725        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 37           |
# |    iterations           | 4            |
# |    time_elapsed         | 220          |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0051568267 |
# |    clip_fraction        | 0.0522       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.25        |
# |    explained_variance   | 0.00441      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.763        |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00393     |
# |    std                  | 0.996        |
# |    value_loss           | 0.864        |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 36         |
# |    iterations           | 5          |
# |    time_elapsed         | 279        |
# |    total_timesteps      | 10240      |
# | train/                  |            |
# |    approx_kl            | 0.00802374 |
# |    clip_fraction        | 0.0842     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.23      |
# |    explained_variance   | 0.00672    |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.781      |
# |    n_updates            | 40         |
# |    policy_gradient_loss | -0.00652   |
# |    std                  | 0.988      |
# |    value_loss           | 0.994      |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 36           |
# |    iterations           | 6            |
# |    time_elapsed         | 339          |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0045274426 |
# |    clip_fraction        | 0.0509       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.22        |
# |    explained_variance   | 0.0155       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.603        |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.00321     |
# |    std                  | 0.99         |
# |    value_loss           | 0.741        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 35           |
# |    iterations           | 7            |
# |    time_elapsed         | 400          |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0064167227 |
# |    clip_fraction        | 0.0571       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.21        |
# |    explained_variance   | 0.0223       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.337        |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00398     |
# |    std                  | 0.982        |
# |    value_loss           | 0.731        |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 35           |
# |    iterations           | 8            |
# |    time_elapsed         | 460          |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0038635263 |
# |    clip_fraction        | 0.0599       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.18        |
# |    explained_variance   | 0.0263       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.458        |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00377     |
# |    std                  | 0.968        |
# |    value_loss           | 0.711        |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 35         |
# |    iterations           | 9          |
# |    time_elapsed         | 519        |
# |    total_timesteps      | 18432      |
# | train/                  |            |
# |    approx_kl            | 0.01004084 |
# |    clip_fraction        | 0.0825     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.14      |
# |    explained_variance   | 0.0343     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.213      |
# |    n_updates            | 80         |
# |    policy_gradient_loss | -0.00558   |
# |    std                  | 0.954      |
# |    value_loss           | 0.678      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 34          |
# |    iterations           | 10          |
# |    time_elapsed         | 585         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.007252723 |
# |    clip_fraction        | 0.0565      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.1        |
# |    explained_variance   | 0.0245      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.572       |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0033     |
# |    std                  | 0.943       |
# |    value_loss           | 1.16        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 11          |
# |    time_elapsed         | 676         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.006831408 |
# |    clip_fraction        | 0.05        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.05       |
# |    explained_variance   | 0.0372      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.4         |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0029     |
# |    std                  | 0.927       |
# |    value_loss           | 0.971       |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 32           |
# |    iterations           | 12           |
# |    time_elapsed         | 754          |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0065599503 |
# |    clip_fraction        | 0.052        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.01        |
# |    explained_variance   | 0.0386       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.718        |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00203     |
# |    std                  | 0.914        |
# |    value_loss           | 0.876        |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 31          |
# |    iterations           | 13          |
# |    time_elapsed         | 835         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.009865088 |
# |    clip_fraction        | 0.0892      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.97       |
# |    explained_variance   | 0.0111      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.3         |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00541    |
# |    std                  | 0.907       |
# |    value_loss           | 2.53        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 31           |
# |    iterations           | 14           |
# |    time_elapsed         | 917          |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0053286487 |
# |    clip_fraction        | 0.058        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.97        |
# |    explained_variance   | 0.029        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.31         |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00309     |
# |    std                  | 0.912        |
# |    value_loss           | 1.45         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 30           |
# |    iterations           | 15           |
# |    time_elapsed         | 1006         |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0012702276 |
# |    clip_fraction        | 0.0151       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.97        |
# |    explained_variance   | 0.0155       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.05         |
# |    n_updates            | 140          |
# |    policy_gradient_loss | 0.00035      |
# |    std                  | 0.91         |
# |    value_loss           | 3.34         |
# ------------------------------------------

# %% [markdown]
# #Save & reload model

# %%
PPO_path = os.path.join('Training', 'Saved Models', 'PPO_Driving_Model')
model.save(PPO_path)

# %%
del model

# %%
model = PPO.load('PPO_model', env=env)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [30], line 1
# ----> 1 model = PPO.load('PPO_model', env=env)
#
# File ~/venv/lib/python3.9/site-packages/stable_baselines3/common/base_class.py:679, in BaseAlgorithm.load(cls, path, env, device, custom_objects, print_system_info, force_reset, **kwargs)
#     676     print("== CURRENT SYSTEM INFO ==")
#     677     get_system_info()
# --> 679 data, params, pytorch_variables = load_from_zip_file(
#     680     path,
#     681     device=device,
#     682     custom_objects=custom_objects,
#     683     print_system_info=print_system_info,
#     684 )
#     686 assert data is not None, "No data found in the saved file"
#     687 assert params is not None, "No params found in the saved file"
#
# File ~/venv/lib/python3.9/site-packages/stable_baselines3/common/save_util.py:390, in load_from_zip_file(load_path, load_data, custom_objects, device, verbose, print_system_info)
#     363 def load_from_zip_file(
#     364     load_path: Union[str, pathlib.Path, io.BufferedIOBase],
#     365     load_data: bool = True,
#    (...)
#     369     print_system_info: bool = False,
#     370 ) -> Tuple[Optional[Dict[str, Any]], TensorDict, Optional[TensorDict]]:
#     371     """
#     372     Load model data from a .zip archive
#     373
#    (...)
#     388         and dict of pytorch variables
#     389     """
# --> 390     load_path = open_path(load_path, "r", verbose=verbose, suffix="zip")
#     392     # set device to cpu if cuda is not available
#     393     device = get_device(device=device)
#
# File /usr/local/lib/python3.9/functools.py:888, in singledispatch.<locals>.wrapper(*args, **kw)
#     884 if not args:
#     885     raise TypeError(f'{funcname} requires at least '
#     886                     '1 positional argument')
# --> 888 return dispatch(args[0].__class__)(*args, **kw)
#
# File ~/venv/lib/python3.9/site-packages/stable_baselines3/common/save_util.py:234, in open_path_str(path, mode, verbose, suffix)
#     219 @open_path.register(str)
#     220 def open_path_str(path: str, mode: str, verbose: int = 0, suffix: Optional[str] = None) -> io.BufferedIOBase:
#     221     """
#     222     Open a path given by a string. If writing to the path, the function ensures
#     223     that the path exists.
#    (...)
#     232     :return:
#     233     """
# --> 234     return open_path(pathlib.Path(path), mode, verbose, suffix)
#
# File /usr/local/lib/python3.9/functools.py:888, in singledispatch.<locals>.wrapper(*args, **kw)
#     884 if not args:
#     885     raise TypeError(f'{funcname} requires at least '
#     886                     '1 positional argument')
# --> 888 return dispatch(args[0].__class__)(*args, **kw)
#
# File ~/venv/lib/python3.9/site-packages/stable_baselines3/common/save_util.py:286, in open_path_pathlib(path, mode, verbose, suffix)
#     279         path.parent.mkdir(exist_ok=True, parents=True)
#     281 # if opening was successful uses the identity function
#     282 # if opening failed with IsADirectory|FileNotFound, calls open_path_pathlib
#     283 #   with corrections
#     284 # if reading failed with FileNotFoundError, calls open_path_pathlib with suffix
# --> 286 return open_path(path, mode, verbose, suffix)
#
# File /usr/local/lib/python3.9/functools.py:888, in singledispatch.<locals>.wrapper(*args, **kw)
#     884 if not args:
#     885     raise TypeError(f'{funcname} requires at least '
#     886                     '1 positional argument')
# --> 888 return dispatch(args[0].__class__)(*args, **kw)
#
# File ~/venv/lib/python3.9/site-packages/stable_baselines3/common/save_util.py:266, in open_path_pathlib(path, mode, verbose, suffix)
#     264             path, suffix = newpath, None
#     265         else:
# --> 266             raise error
#     267 else:
#     268     try:
#
# File ~/venv/lib/python3.9/site-packages/stable_baselines3/common/save_util.py:258, in open_path_pathlib(path, mode, verbose, suffix)
#     256 if mode == "r":
#     257     try:
# --> 258         path = path.open("rb")
#     259     except FileNotFoundError as error:
#     260         if suffix is not None and suffix != "":
#
# File /usr/local/lib/python3.9/pathlib.py:1252, in Path.open(self, mode, buffering, encoding, errors, newline)
#    1246 def open(self, mode='r', buffering=-1, encoding=None,
#    1247          errors=None, newline=None):
#    1248     """
#    1249     Open the file pointed by this path and return a file object, as
#    1250     the built-in open() function does.
#    1251     """
# -> 1252     return io.open(self, mode, buffering, encoding, errors, newline,
#    1253                    opener=self._opener)
#
# File /usr/local/lib/python3.9/pathlib.py:1120, in Path._opener(self, name, flags, mode)
#    1118 def _opener(self, name, flags, mode=0o666):
#    1119     # A stub for the opener argument to built-in open()
# -> 1120     return self._accessor.open(self, flags, mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'PPO_model.zip'

# %% [markdown]
# #Evaluation

# %%
evaluate_policy(model, env, n_eval_episodes=10, render=True)
#Returns average reward, and std(standard deviation)
# Out:
# /root/venv/lib/python3.9/site-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# (500.0, 0.0)

# %%
env.close()

# %% [markdown]
# #Test model

# %%
episodes = 5
for episode in range(1, episodes+1):
    obs = env.reset()
    done = False
    score = 0

    while not done:
        env.render()
        action, _ = model.predict(obs)
        obs, reward, done, info = env.step(action)
        score += reward
    print('Episode:{} Score;:{}'.format(episode,score))
#env.close()
'''obs = env.reset()
while True:
    action, _states = model.predict(obs)
    obs, rewards, done, info = env.step(action)
    env.render()
    if done: 
        print('info', info)
        break'''
# Out:
# info [{'TimeLimit.truncated': True, 'terminal_observation': array([ 0.16268091, -0.00250308, -0.01878624,  0.09337898], dtype=float32)}]

# %%
episodes = 5 #an episode is a full game within the environment
for episode in range(1, episodes+1):
    obs = env.reset() #Get initial set of observations
    terminated = False
    score = 0 
    
    while not terminated:
        env.render() #visualize environment graph representation. Donesn´t work in collabs
        
        action, _ = model.predict(obs)#Returns a sample from the action_space

        obs, reward, terminated, info = env.step(action) #apply an action to the environment
        score+=reward
    print('Episode:{} Score:{}'.format(episode, score))
#env.close() #Close down the render frame
# Out:
# Episode:1 Score:[500.]
# Episode:2 Score:[500.]
# Episode:3 Score:[500.]
# Episode:4 Score:[500.]
# Episode:5 Score:[500.]

# %%
env.close()

# %% [markdown]
# #Viewing logs in Tensorboard

# %%
#You can view metrics from within Tensorboard!
model = A2C("CnnPolicy", env, verbose=, tensorboard_log=log_path)

# %%
training_log_path = os.path.join(log_path, 'PPO_3')
training_log_path
# Out:
# 'training/Logs/PPO_3'

# %%
#Starting tensorboard
# !tensorboard --logdir = {training_log_path}#log_path

# %%
 # Import Callback helpers
 '''
 from stable_baselines3.common.callbacks import EvalCallback, StopTrainingOnRewardThreshold
 ''' 

 #Setup Callbacks
 '''
 stop_callback = StopTrainingOnRewardThreshold(reward_threshold=190, verbose=1)
 eval_callback = EvalCallback(env, callback_on_new_best=stop_callback, eval_freq=10000, best_model_save_path = save_path, verbose=1)
 '''

 #Apply Callbacks to train step
 '''
 model.learn(total_timesteps = 20000, callback=eval_callback)
 '''

# %%
import os
save_path = os.path.join('Training', 'Saved Models')
log_path = os.path.join('Training', 'Logs')

# %%
env = gym.make(environment_name)
env = DummyVecEnv([lambda: env])

# %% [markdown]
# #Adding a callback to the training stage

# %%
from stable_baselines3.common.callbacks import EvalCallback, StopTrainingOnRewardThreshold

# %%
stop_callback = StopTrainingOnRewardThreshold(reward_threshold=190, verbose=1)
eval_callback = EvalCallback(env, 
                             callback_on_new_best=stop_callback, 
                             eval_freq=10000, #Evaluation each 10000 training cases
                             best_model_save_path=save_path, 
                             verbose=1)

# %%
model = PPO('MlpPolicy', env, verbose = 1, tensorboard_log=log_path)#same as in training model step

# %%
model.learn(total_timesteps=20000, callback=eval_callback)

# %%
model_path = os.path.join('Training', 'Saved Models', 'best_model')
model = PPO.load(model_path, env=env)

# %%
evaluate_policy(model, env, n_eval_episodes=10, render=True)

# %%
env.close()

# %% [markdown]
# #Changing policies

# %%
#Define new MLP network
net_arch=[dict(pi=[128, 128, 128, 128], vf=[128, 128, 128, 128])]#value function. neurons/layer
#net_arch=[128,128]#Equivalently

# %%
#Apply Network
model = PPO('MlpPolicy', env, verbose = 1, policy_kwargs={'net_arch': net_arch})#tensorboard_log=log_path

# %%
model.learn(total_timesteps=20000, callback=eval_callback)

# %% [markdown]
# #Using alternate algorithm

# %%
from stable_baselines3 import DQN

# %%
model = DQN('MlpPolicy', env, verbose = 1, tensorboard_log=log_path)

# %%
model.learn(total_timesteps=20000, callback=eval_callback)

# %%
dqn_path = os.path.join('Training', 'Saved Models', 'DQN_model')

# %%
model.save(dqn_path)

# %%
model = DQN.load(dqn_path, env=env)

# %%
evaluate_policy(model, env, n_eval_episodes=10, render=True)

# %%
env.close()

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=ef02c85f-446f-4608-88fc-10a0b6552851' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
